# %%
import pickle
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
test_input2 = pd.DataFrame(
    [[2, 'female', 31.0, 1, 1, 26.25, 'S', 'Mrs', 2, 0, 1]],
    columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Title', 'FamilySize', 'IsAlone', 'HasCabin']
)

# %%
print(pipe.predict(test_input2))
# Out:
# [1]
